# %%
import numpy as np
import pandas as pd

# %%
eth_df = pd.read_csv('/Users/newuser/Dropbox/Datamining/Crypto-Pirates/Datasets/ethereum_price.csv')
new_index = eth_df['Date']
eth_df.head()
# Out:
#            Date    Open    High     Low   Close       Volume      Market Cap
# 0  Nov 07, 2017  298.57  304.84  290.77  294.66  540,766,000  28,533,300,000
# 1  Nov 06, 2017  296.43  305.42  293.72  298.89  579,359,000  28,322,700,000
# 2  Nov 05, 2017  300.04  301.37  295.12  296.26  337,658,000  28,661,500,000
# 3  Nov 04, 2017  305.48  305.48  295.80  300.47  416,479,000  29,175,300,000
# 4  Nov 03, 2017  288.50  308.31  287.69  305.71  646,340,000  27,547,400,000

# %% [markdown]
# ### Adding Columns

# %%
eth_df['Daily Range'] = eth_df['High'] - eth_df['Low']
eth_df.head()
# Out:
#            Date    Open    High     Low   Close       Volume      Market Cap  \
# 0  Nov 07, 2017  298.57  304.84  290.77  294.66  540,766,000  28,533,300,000
# 1  Nov 06, 2017  296.43  305.42  293.72  298.89  579,359,000  28,322,700,000
# 2  Nov 05, 2017  300.04  301.37  295.12  296.26  337,658,000  28,661,500,000
# 3  Nov 04, 2017  305.48  305.48  295.80  300.47  416,479,000  29,175,300,000
# 4  Nov 03, 2017  288.50  308.31  287.69  305.71  646,340,000  27,547,400,000
#
#    Daily Range
# 0        14.07
# 1        11.70
# 2         6.25
# 3         9.68
# 4        20.62

# %% [markdown]
# ### Adding the mean

# %%
eth_df['Daily Range'].mean()
# Out:
# 5.8695899150485422

# %%
'''
1. Add new column. 2. Define Conditions. 3. Change necessary value to the column that meets the condition.
'''

eth_df['Significant'] = ''

cond1 = eth_df['Daily Range'] > eth_df['Daily Range'].mean()
cond2 = eth_df['Daily Range'] < eth_df['Daily Range'].mean()

yes = eth_df[cond1]
no = eth_df[cond2]

column = 'Significant'
eth_df.loc[cond1, column] = 'Yes'
eth_df.loc[cond2, column] = 'No'
eth_df.set_index('Significant')
# Out:
#                      Date        Open        High         Low       Close  \
# Significant
# Yes          Nov 07, 2017  298.570000  304.840000  290.770000  294.660000
# Yes          Nov 06, 2017  296.430000  305.420000  293.720000  298.890000
# Yes          Nov 05, 2017  300.040000  301.370000  295.120000  296.260000
# Yes          Nov 04, 2017  305.480000  305.480000  295.800000  300.470000
# Yes          Nov 03, 2017  288.500000  308.310000  287.690000  305.710000
# Yes          Nov 02, 2017  290.730000  293.910000  281.170000  287.430000
# Yes          Nov 01, 2017  305.760000  306.400000  290.580000  291.690000
# No           Oct 31, 2017  307.380000  310.550000  305.880000  305.880000
# Yes          Oct 30, 2017  304.780000  310.500000  304.350000  307.750000
# Yes          Oct 29, 2017  296.380000  313.750000  296.380000  305.090000
# Yes          Oct 28, 2017  297.920000  300.360000  293.580000  296.300000
# ...

# %% [markdown]
# ### Reading in BTC, LTC, ETH, MONERO

# %%
eth1 = pd.read_csv('/Users/newuser/Dropbox/Datamining/Crypto-Pirates/Datasets/bitcoin_price.csv')
eth2 = pd.read_csv('/Users/newuser/Dropbox/Datamining/Crypto-Pirates/Datasets/monero_price.csv')
eth3 = pd.read_csv('/Users/newuser/Dropbox/Datamining/Crypto-Pirates/Datasets/litecoin_price.csv')
eth4 = pd.read_csv('/Users/newuser/Dropbox/Datamining/Crypto-Pirates/Datasets/ethereum_price.csv')

# %% [markdown]
# ### Concatenating 4 Data Frames

# %%
eth1['CC'] = 'Bitcoin'
eth2['CC'] = 'Monero'
eth3['CC'] = 'Litecoin'
eth4['CC'] = 'Ethereum'
master_df = pd.concat([eth1,eth2,eth3,eth4])
# set new index
master_df.set_index('CC', inplace=True)
master_df
# Out:
#                   Date         Open         High          Low        Close  \
# CC
# Bitcoin   Oct 03, 2017  4408.460000  4432.470000  4258.890000  4317.480000
# Bitcoin   Oct 02, 2017  4395.810000  4470.230000  4377.460000  4409.320000
# Bitcoin   Oct 01, 2017  4341.050000  4403.740000  4269.810000  4403.740000
# Bitcoin   Sep 30, 2017  4166.110000  4358.430000  4160.860000  4338.710000
# Bitcoin   Sep 29, 2017  4171.620000  4214.630000  4039.290000  4163.070000
# Bitcoin   Sep 28, 2017  4197.130000  4279.310000  4109.700000  4174.730000
# Bitcoin   Sep 27, 2017  3892.940000  4210.050000  3884.820000  4200.670000
# Bitcoin   Sep 26, 2017  3928.410000  3969.890000  3869.900000  3892.350000
# Bitcoin   Sep 25, 2017  3681.580000  3950.250000  3681.580000  3926.070000
# Bitcoin   Sep 24, 2017  3796.150000  3796.150000  3666.900000  3682.840000
# Bitcoin   Sep 23, 2017  3629.920000  3819.210000  3594.580000  3792.400000
# ...

# %% [markdown]
# ### Means of the 4 CC's

# %%
master_df.groupby('CC').mean()
# Out:
#                 Open        High         Low       Close
# CC
# Bitcoin   716.325031  736.272765  696.893778  718.804210
# Ethereum   68.758298   71.660280   65.790691   69.098058
# Litecoin    9.302488    9.737444    8.843586    9.330123
# Monero     10.668743   11.325722   10.091139   10.740487

# %%
master_df.groupby('CC').describe().transpose()
# Out:
# CC               Bitcoin    Ethereum     Litecoin       Monero
# Open  count  1620.000000  824.000000  1620.000000  1231.000000
#       mean    716.325031   68.758298     9.302488    10.668743
#       std     841.566485  112.338764    13.103364    22.366494
#       min      68.500000    0.431589     1.150000     0.220121
#       25%     261.080000    6.387500     3.070000     0.514239
#       50%     448.150000   11.390000     3.845000     1.380000
#       75%     705.347500   49.925000     8.675000     9.380000
#       max    4901.420000  397.590000    85.830000   144.240000
# High  count  1620.000000  824.000000  1620.000000  1231.000000
#       mean    736.272765   71.660280     9.737444    11.325722
#       std     870.749477  116.531656    13.847245    23.724047
#       min      74.560000    0.482988     1.340000     0.251757
#       25%     266.462500    6.642500     3.120000     0.542731
#       50%     454.645000   11.695000     3.910000     1.500000
# ...
